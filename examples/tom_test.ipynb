# %% [markdown]
# # Notebook to test if Tom's atlite cloud is working

# %%
from atlite import Cutout

cutout = Cutout('test-cutout.nc', x=slice(6, 8), y=slice(52, 54), module="tz_era5", time=slice("2013-01-01", "2013-12-31"))
cutout.prepare()
# Out:
# /Users/calvinnesbitt/Documents/feo/energy_modelling/atlite/atlite/datasets/tz_era5.py:65: UserWarning: No Google Cloud credentials found in environment variables. Will try using default credentials instead.
#   warnings.warn(
# /Users/calvinnesbitt/Documents/feo/energy_modelling/atlite/atlite/cutout.py:186: UserWarning: Arguments x, y, module, time are ignored, since cutout is already built.
#   warn(
# <Cutout "test-cutout">
#  x = 6.00 ⟷ 8.00, dx = 0.25
#  y = 52.00 ⟷ 54.00, dy = 0.25
#  time = 2013-01-01 ⟷ 2013-12-31, dt = H
#  module = tz_era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature', 'runoff']

# %%
cutout.data.wnd100m.isel(time=0).plot(x='x')
