# %% [markdown]
# # Notebook to test if Tom's atlite cloud is working

# %%
from atlite import Cutout

cutout = Cutout('test-cutout-4.nc', x=slice(6, 8), y=slice(52, 54), module="tz_era5", time=slice("2012-01-01", "2013-12-31"))
cutout.prepare()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 from atlite import Cutout
#       3 cutout = Cutout('test-cutout-4.nc', x=slice(6, 8), y=slice(52, 54), module="tz_era5", time=slice("2012-01-01", "2013-12-31"))
# ----> 4 cutout.prepare()
#
# File ~/Documents/feo/energy_modelling/atlite/atlite/data.py:104, in maybe_remove_tmpdir.<locals>.wrapper(*args, **kwargs)
#     102 kwargs["tmpdir"] = mkdtemp()
#     103 try:
# --> 104     res = func(*args, **kwargs)
#     105 finally:
#     106     rmtree(kwargs["tmpdir"])
#
# File ~/Documents/feo/energy_modelling/atlite/atlite/data.py:178, in cutout_prepare(cutout, features, tmpdir, overwrite, compression)
#     176 logger.info(f"Calculating and writing with module {module}:")
#     177 missing_features = missing_vars.index.unique("feature")
# ...

# %%
cutout.data.wnd100m.isel(time=0).plot(x='x')
