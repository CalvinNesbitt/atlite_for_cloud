# %% [markdown]
# # Notebook to test if Tom's atlite cloud is working

# %%
from atlite import Cutout

cutout = Cutout('small-test-cutout.nc', x=slice(6, 8), y=slice(52, 54), module="tz_era5", time=slice("2013-01-01","2013-12-31"))
cutout.prepare()
# Out:
# /Users/calvinnesbitt/Documents/feo/energy_modelling/atlite/atlite/cutout.py:186: UserWarning: Arguments x, y, module, time are ignored, since cutout is already built.
#   warn(
# <Cutout "small-test-cutout">
#  x = 6.00 ⟷ 8.00, dx = 0.25
#  y = 52.00 ⟷ 54.00, dy = 0.25
#  time = 2013-01-01 ⟷ 2013-01-02, dt = H
#  module = tz_era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature', 'runoff']

# %%
cutout.data
# Out:
# <xarray.Dataset>
# Dimensions:           (x: 9, y: 9, time: 48)
# Coordinates:
#   * x                 (x) float64 6.0 6.25 6.5 6.75 7.0 7.25 7.5 7.75 8.0
#   * y                 (y) float64 52.0 52.25 52.5 52.75 ... 53.5 53.75 54.0
#   * time              (time) datetime64[ns] 2013-01-01 ... 2013-01-02T23:00:00
#     lon               (x) float64 dask.array<chunksize=(9,), meta=np.ndarray>
#     lat               (y) float64 dask.array<chunksize=(9,), meta=np.ndarray>
# Data variables: (12/13)
#     height            (x, y) float32 dask.array<chunksize=(9, 9), meta=np.ndarray>
#     wnd100m           (x, y, time) float32 dask.array<chunksize=(9, 9, 48), meta=np.ndarray>
#     wnd_azimuth       (x, y, time) float32 dask.array<chunksize=(9, 9, 48), meta=np.ndarray>
#     roughness         (x, y, time) float32 dask.array<chunksize=(9, 9, 48), meta=np.ndarray>
#     influx_toa        (x, y, time) float32 dask.array<chunksize=(9, 9, 48), meta=np.ndarray>
# ...
